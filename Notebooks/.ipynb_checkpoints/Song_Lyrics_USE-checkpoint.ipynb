# %% [markdown]
# <img src="assets/header'jpeg" style="width: 800px;">

# %% [markdown]
# # `Contents:`
#
# - [Background](#background)
# - [What is a network?](#whatisanetwork)
# - [A Game of Networks](#agameofnetworks)
# - [Load Libraries](#loadlibraries)
#
# - [Load Edges & Nodes](#loadedgesandnodes)
# 	- [Exploring the nodes](#exploringthenodes)
# 	- [Exploring the edges](#exploringtheedges)
# 	- [Building the graph](#buildingthegraph)
# 	- [Drawing the graph](#drawingthegraph)
#
# - [Graph Metrics](#graphmetrics)
# 	- [Degree](#degree)
# 	- [Betweeness Centrality](#betweenesscentrality)
# 	- [Degree and Betweeness Centrality - is there a relationship?](#degreeandbetweenesscentrality)
# 	- [Building up the node dataframe](#buildingupthenodedataframe)
# 	- [Building up the edge dataframe](#buildinguptheedgedataframe)
#
# - [Plotting Tools](#plottingtools)
# 	- [Filtered Graph Plotter](#filteredgraphplotter)
#
# - [Ways we can use network science to answer questions about the characters](#questions)
# 	- [Which character pairings occur most often?](#often)
# 	- [Who is the most devoted character?](#devoted)
# 	- [What characters are yet to meet?](#unconnected)
# 	- [What house is the most important?](#house)

# %%
#data / numbers
import pandas as pd
pd.options.plotting.backend = "plotly"
import numpy as np
import string
import itertools

#NLP
import gensim
import spacy

#sklearn
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from sklearn.feature_extraction import text
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS 


#PCA
from sklearn.decomposition import PCA
import contractions as ct

#viz

import plotly
import plotly.graph_objs as go

import plotly.express as px

from plotly.offline import download_plotlyjs, iplot, plot
import chart_studio
import plotly.figure_factory as ff
import chart_studio.plotly as py
chart_studio.tools.set_credentials_file(username='kitsamho', api_key='JPuAu5Xtf7BhX43kDd4m')

import tensorflow as tf
import tensorflow_hub as hub

# %% [markdown]
# ### Read in data..

# %%
df = pd.read_csv('../Lyric_data/lyrics.csv') #read in csv

# %%
#drop any dupes
df.drop_duplicates(subset=['song'],inplace=True)

# %%
#reset index
df.reset_index(drop=True,inplace=True)

# %%
#formatting
df.lyrics = df.lyrics.map(lambda x: x.lower())
df.artist = df.artist.map(lambda x: x.replace('Iggy and The Stooges 3','Iggy and The Stooges'))

# %%
def fixContractions(text):
    
    """Function used contractions library to fix contractions and normalise slang"""
    
    return ct.fix(text)

# %%
df.lyrics = df.lyrics.map(fixContractions)

# %% [markdown]
# Let's look at what we have..

# %%
df.head(3)
# Out:
#        artist                song  \
# 0  Snoop Dogg           Hollywood
# 1  Snoop Dogg  I Wanna Go Outside
# 2  Snoop Dogg     Bitch Please II
#
#                                               lyrics
# 0  where the beautiful people at? i said where th...
# 1  yes and we are back here at the jack-off hour ...
# 2  yeah, what up detroit nu-uh, nu-uh nuh no he d...

# %% [markdown]
# ### Get Genres

# %%
#look at all our artists
df.artist.unique()
# Out:
# array(['Snoop Dogg', 'Cannibal Corpse', 'Kanye West', 'Nine Inch Nails',
#        'AC DC', 'The Rolling Stones', 'Public Enemy', 'Alice In Chains',
#        'Cradle of Filth', 'Metallica', 'The Beatles', 'Slayer', 'Adele',
#        'JAY Z', 'Nirvana', 'Green Day', 'Motley Crue', 'Stevie Wonder',
#        'Sex Pistols', 'Elton John', 'Queen', 'Stormzy', 'Megadeth',
#        'Madonna', 'U2', 'Drake', 'Coldplay', 'Pearl Jam',
#        'Stone Temple Pilots', 'Bon Jovi', 'Iron Maiden', 'Black Sabbath',
#        'Judas Priest', 'Michael Jackson', 'Taylor Swift', 'Lady Gaga',
#        'Maroon 5', 'Sam Smith', 'Marvin Gaye', 'Luther Vandross',
#        'Lionel Richie', 'Carcass', 'Death', 'Exhumed', 'Ramones',
#        'The Clash', 'Iggy and The Stooges', 'Selena Gomez', 'Anthrax',
#        'Red Hot Chili Peppers', 'George Michael', 'Aretha Franklin'],
#       dtype=object)

# %%
#setting up genre labels for each artist
genres = ['hip-hop/rap','death-metal','hip-hop/rap',
          'alternative','rock','rock','hip-hop/rap',
          'alternative','death-metal','metal',
          'pop','metal','soul','hip-hop/rap','alternative','alternative',
          'rock','soul','punk','pop','rock','hip-hop/rap','metal',
          'pop','pop/rock','hip-hop/rap','pop/rock','alternative',
          'alternative','rock','metal','metal','metal','pop','pop','pop',
          'pop/rock','soul','soul','soul','soul','death-metal','death-metal','death-metal',
          'punk','punk','punk','pop','metal','alternative','pop','soul']

# %%
#make a genre dictionary
genre_dic = dict(zip(df.artist.unique(),genres))

# %%
genre_dic
# Out:
# {'Snoop Dogg': 'hip-hop/rap',
#  'Cannibal Corpse': 'death-metal',
#  'Kanye West': 'hip-hop/rap',
#  'Nine Inch Nails': 'alternative',
#  'AC DC': 'rock',
#  'The Rolling Stones': 'rock',
#  'Public Enemy': 'hip-hop/rap',
#  'Alice In Chains': 'alternative',
#  'Cradle of Filth': 'death-metal',
#  'Metallica': 'metal',
#  'The Beatles': 'pop',
#  'Slayer': 'metal',
#  'Adele': 'soul',
#  'JAY Z': 'hip-hop/rap',
#  'Nirvana': 'alternative',
#  'Green Day': 'alternative',
#  'Motley Crue': 'rock',
#  'Stevie Wonder': 'soul',
#  'Sex Pistols': 'punk',
#  'Elton John': 'pop',
#  'Queen': 'rock',
#  'Stormzy': 'hip-hop/rap',
#  'Megadeth': 'metal',
#  'Madonna': 'pop',
#  'U2': 'pop/rock',
#  'Drake': 'hip-hop/rap',
#  'Coldplay': 'pop/rock',
#  'Pearl Jam': 'alternative',
#  'Stone Temple Pilots': 'alternative',
#  'Bon Jovi': 'rock',
#  'Iron Maiden': 'metal',
#  'Black Sabbath': 'metal',
#  'Judas Priest': 'metal',
#  'Michael Jackson': 'pop',
#  'Taylor Swift': 'pop',
#  'Lady Gaga': 'pop',
#  'Maroon 5': 'pop/rock',
#  'Sam Smith': 'soul',
#  'Marvin Gaye': 'soul',
#  'Luther Vandross': 'soul',
#  'Lionel Richie': 'soul',
#  'Carcass': 'death-metal',
#  'Death': 'death-metal',
#  'Exhumed': 'death-metal',
#  'Ramones': 'punk',
#  'The Clash': 'punk',
#  'Iggy and The Stooges': 'punk',
#  'Selena Gomez': 'pop',
#  'Anthrax': 'metal',
#  'Red Hot Chili Peppers': 'alternative',
#  'George Michael': 'pop',
#  'Aretha Franklin': 'soul'}

# %%
#add genre columns
df['genre'] = df.artist.map(lambda x: genre_dic[x])

# %% [markdown]
# ### Count word frequencies for each song

# %%
#get lyric frequencies for each song
df['lyric_count'] = df['lyrics'].map(lambda x: len(x.split()))

# %% [markdown]
# For plotting, we need to scale back the data in order for the traces to be the right size for the Plotly visualisations

# %%
#normalise lyric counts
norm = [float(i)/max(df.lyric_count) for i in df.lyric_count]

# %%
#get column for normalised data
df['lyric_count_norm'] = norm

# %%
#scale it up
df['lyric_count_norm'] = df['lyric_count_norm'].map(lambda x: x*55)

# %% [markdown]
# Let's look at what we have..

# %%
df.head(3)
# Out:
#        artist                song  \
# 0  Snoop Dogg           Hollywood
# 1  Snoop Dogg  I Wanna Go Outside
# 2  Snoop Dogg     Bitch Please II
#
#                                               lyrics        genre  \
# 0  where the beautiful people at? i said where th...  hip-hop/rap
# 1  yes and we are back here at the jack-off hour ...  hip-hop/rap
# 2  yeah, what up detroit nu-uh, nu-uh nuh no he d...  hip-hop/rap
#
#    lyric_count  lyric_count_norm
# 0          302         10.234134
# 1          428         14.504005
# 2          738         25.009242

# %% [markdown]
# ### Get a unique artist code (for plotting)

# %% [markdown]
# We need to get some unique codes in order to be able to colour our traces

# %%
#get a unique code for each artists
artist_code = [i for i in range(len(df.artist.unique()))]

#get a dictionary
artist_dic = dict(zip(df.artist.unique(),artist_code))

#add artist code as column
df['artist_coding'] = df.artist.map(lambda x: artist_dic[x])

# %% [markdown]
# ### Get a genre code (for plotting)

# %% [markdown]
# As above - but for genre

# %%
#get a unique code for each genre
genre_code = [i for i in range(len(df.genre.unique()))]

#get a dictionary
genre_code_dic = dict(zip(df.genre.unique(),genre_code))

#add genre code as column
df['genre_coding'] = df.genre.map(lambda x: genre_code_dic[x])

# %% [markdown]
# Let's look at what we have..

# %%
df.head(3)
# Out:
#        artist                song  \
# 0  Snoop Dogg           Hollywood
# 1  Snoop Dogg  I Wanna Go Outside
# 2  Snoop Dogg     Bitch Please II
#
#                                               lyrics        genre  \
# 0  where the beautiful people at? i said where th...  hip-hop/rap
# 1  yes and we are back here at the jack-off hour ...  hip-hop/rap
# 2  yeah, what up detroit nu-uh, nu-uh nuh no he d...  hip-hop/rap
#
#    lyric_count  lyric_count_norm  artist_coding  genre_coding
# 0          302         10.234134              0             0
# 1          428         14.504005              0             0
# 2          738         25.009242              0             0

# %% [markdown]
# # EDA

# %% [markdown]
# Before we start looking at sentence embeddings, let's have a little explore of what data we have

# %% [markdown]
# ## Count of Genre

# %%
#plot genres
fig_genre = pd.DataFrame(df.genre.value_counts()).plot.bar(template='ggplot2')

#title parameters
title_param = dict(text='<b>Count of Genre</b><br></b>', 
                        font=dict(size=20))

#update layout
fig_genre.update_layout(title=title_param,
                  width=1000,
                  height=500,        
                  xaxis = dict(title='Genre'),
                  yaxis = dict(title='Count'),
                  autosize=False,
                  showlegend=False,)

fig_genre.update_traces(marker_color='rgb(148, 103, 189)')
#show plot
fig_genre.show()
# Out:
# <div>
#
#
#             <div id="a321ce3a-6149-4015-a02e-eb672afba43e" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a321ce3a-6149-4015-a02e-eb672afba43e")) {
#                     Plotly.newPlot(
#                         'a321ce3a-6149-4015-a02e-eb672afba43e',
#                         [{"alignmentgroup": "True", "hovertemplate": "variable=genre<br>index=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "genre", "marker": {"color": "rgb(148, 103, 189)"}, "name": "genre", "offsetgroup": "genre", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["pop", "alternative", "metal", "soul", "hip-hop/rap", "rock", "pop/rock", "death-metal", "punk"], "xaxis": "x", "y": [299, 272, 256, 195, 195, 191, 140, 86, 58], "yaxis": "y"}],
#                         {"autosize": false, "barmode": "relative", "height": 500, "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "rgb(51,51,51)"}, "error_y": {"color": "rgb(51,51,51)"}, "marker": {"line": {"color": "rgb(237,237,237)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(237,237,237)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(51,51,51)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(51,51,51)"}, "baxis": {"endlinecolor": "rgb(51,51,51)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(51,51,51)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237 ...

# %% [markdown]
# ## Count of Artist / Band

# %%
fig_artist = pd.DataFrame(df.artist.value_counts()).plot.barh(template='ggplot2')

#title parameters
title_param = dict(text='<b>Count of Artist</b><br></b>', 
                        font=dict(size=20))

#update layout
fig_artist.update_layout(title=title_param,
                  width=1000,
                  height=1000,        
                  xaxis = dict(title='Song Count'),
                  yaxis = dict(title='Artist'),
                  autosize=False,
                  showlegend=False,)

fig_artist.update_traces(marker_color='rgb(148, 103, 189)')
#show plot
fig_artist.show()
# Out:
# <div>
#
#
#             <div id="69d06824-7abf-477a-9170-9e3005e29f9f" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("69d06824-7abf-477a-9170-9e3005e29f9f")) {
#                     Plotly.newPlot(
#                         '69d06824-7abf-477a-9170-9e3005e29f9f',
#                         [{"alignmentgroup": "True", "hovertemplate": "variable=artist<br>value=%{x}<br>index=%{y}<extra></extra>", "legendgroup": "artist", "marker": {"color": "rgb(148, 103, 189)"}, "name": "artist", "offsetgroup": "artist", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [58, 56, 48, 47, 43, 43, 43, 43, 43, 42, 42, 42, 42, 42, 42, 41, 41, 41, 41, 41, 40, 40, 40, 39, 39, 39, 36, 33, 32, 32, 31, 28, 28, 28, 26, 25, 24, 24, 23, 23, 23, 22, 21, 20, 19, 17, 16, 16, 15, 9, 2, 1], "xaxis": "x", "y": ["Kanye West", "Coldplay", "Metallica", "Alice In Chains", "Slayer", "Adele", "Red Hot Chili Peppers", "U2", "Michael Jackson", "Taylor Swift", "The Rolling Stones", "Nirvana", "Lady Gaga", "AC DC", "Bon Jovi", "Maroon 5", "Sam Smith", "Green Day", "Stormzy", "Drake", "Iron Maiden", "The Beatles", "Megadeth", "Selena Gomez", "Queen", "Pearl Jam", "Madonna", "Judas Priest", "Nine Inch Nails", "Elton John", "Stevie Wonder", "Black Sabbath", "Stone Temple Pilots", "Exhumed", "Motley Crue", "George Michael", "Lionel Richie", "Anthrax", "Snoop Dogg", "JAY Z", "Aretha Franklin", "The Clash", "Cradle of Filth", "Ramones", "Death", "Marvin Gaye", "Luther Vandross", "Cannibal Corpse", "Sex Pistols", "Public Enemy", "Carcass", "Iggy and The Stooges"], "yaxis": "y"}],
#                         {"autosize": false, "barmode": "relative", "height": 1000, "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "rgb(51,51,51)"}, "error_y": {"color": "rgb(51,51,51)"}, "marker": {"line": {"color": "rgb(237,237,237)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(237,237,237)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(51,51,51)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(51,51,51)"}, "baxis": {"endlinecolor": "rgb(51,51,51)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(51,51,51)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,23 ...

# %% [markdown]
# ## Distribution of Lyric Length, by genre

# %%
#empty list
lyric_count_df = []

# %%
#loop through each unique genre
for i in df.genre.unique():
    
    #get subset of genres appended to list
    lyric_count_df.append(pd.DataFrame(df[df.genre == i]['lyric_count']))
    
#concat all DataFrames where each column is a genre
word_counts = pd.concat([i for i in lyric_count_df],axis=1)

# %%
#update columns
word_counts.columns = df.genre.unique()

# %%
#plot lyric count distributon for each genre
fig_dist = word_counts.plot.box(template='ggplot2')



#title parameters
title_param = dict(text='<b>Distribution of lyric length by genre</b><br></b>', 
                        font=dict(size=20))

#update layout
fig_dist.update_layout(title=title_param,
                  width=1000,
                  height=700,        
                  xaxis = dict(title='Genre'),
                  yaxis = dict(title='Song lyric length (n words)'),
                  autosize=False,
                  showlegend=False,)

fig_dist.update_traces(marker_color='rgb(148, 103, 189)')
#show plot
fig_dist.show()
# Out:
# <div>
#
#
#             <div id="56c50172-7f1c-4be3-945e-5fe4092f8bfb" class="plotly-graph-div" style="height:700px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("56c50172-7f1c-4be3-945e-5fe4092f8bfb")) {
#                     Plotly.newPlot(
#                         '56c50172-7f1c-4be3-945e-5fe4092f8bfb',
#                         [{"alignmentgroup": "True", "hovertemplate": "variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "rgb(148, 103, 189)"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-hop/rap", "hip-ho ...

# %% [markdown]
# # PoS Analysis

# %% [markdown]
# In order to perform part of speech analysis we need use something like spaCy

# %%
#load spacy model
nlp = spacy.load('en_core_web_lg')

# %%
def pos(string,pos):
    
    """Returns any token that qualifies as a specific part of speech"""
    
    doc = nlp(string) #fit model
    
    return ' '.join(list(set([i.text for i in doc if i.pos_ == pos]))) #return any tokens that qualify

# %%
#get nouns
df['nouns'] = df.lyrics.map(lambda x: pos(x,'NOUN'))

# %%
#get verbs
df['verbs'] = df.lyrics.map(lambda x: pos(x,'VERB'))

# %%
#get adjectives
df['adjectives'] = df.lyrics.map(lambda x: pos(x,'ADJ'))

# %%
#get adverbs
df['adverbs'] = df.lyrics.map(lambda x: pos(x,'ADV'))

# %% [markdown]
# Let's inspect the new columns..

# %%
# subset on new columns
df.iloc[200:204][df.columns[8:]]
# Out:
#                                                  nouns  \
# 200  taste sweetie woo traps hands vain ministers n...
# 201  shoes arm line face carryin bar tonight woman ...
# 202  reds fruits shoes child wine shit ha friend sp...
# 203  mind glimpse woods babe baby time park love da...
#
#                                                  verbs  \
# 200  hope get made stank mean call let meet sealed ...
# 201  knew let keep see loose getting come dressed d...
# 202  scrape drop thank come said stop beg want help...
# 203  torn looked ripped swirling taken followed wai...
#
#                                             adjectives  \
# 200                   round sure long criminal pleased
# 201                       loose drunk corny wrong more
# 202                                stormy sweet bitter
# 203  strong hooked sweet scared seedy neat hard dar...
#
#                                        adverbs
# 200  around well down damn just after all when
# 201            maybe just about no never right
# 202                                 down right
# 203                   just so anywhere someday

# %% [markdown]
# A function that can count the most common PoS will be helpful

# %%
def mostcommonTokens(data,additional_stopwords = [],token=1):
    
    """Returns a DataFrame of the most common n (arg)tokens in a string. Excludes stop words. Additional
    stop words can be added"""
    
    #add any new stop words to default stopword list
    add_stop_words = ENGLISH_STOP_WORDS.union(additional_stopwords)

    #instantiate count vectorizer and specify tokens
    vect = CountVectorizer(stop_words=add_stop_words, ngram_range= (token,token))

    #fit vectorizer
    X = vect.fit_transform(data)
    
    #get word counts as DataFrame
    word_counts = pd.DataFrame(np.asarray(X.sum(axis=0))[0],vect.get_feature_names(),columns=['count'])
    
    #sort by count
    word_counts = word_counts.sort_values(by='count', ascending=False)

    return word_counts #return DataFrame

# %% [markdown]
# Lets look at the top 10 words in the whole lyric corpus

# %%
#call the function on one gram
mostcommonTokens(df.lyrics,token=1).head(10)
# Out:
#       count
# like   2179
# yeah   2097
# know   2059
# oh     2057
# love   2018
# just   1947
# got    1923
# want   1584
# time   1190
# baby   1105

# %% [markdown]
# We can integrate the mostcommonTokens function with Treemap visualisations to make the analysis clearer

# %%
def genreMap(df,pos,n=100):
    
    """Visualisation function. Returns a treemap of the most common n tokens that qualify as a part of speech"""
    
    #list to populate subset DataFrame's
    all_df = []

    #loop through unique genres
    for i in df.genre.unique():

        #get most common tokens for part of speech
        temp_df = mostcommonTokens(df[df['genre'] == i][pos]).head(n)
        
        #add column for current genre
        temp_df['genre'] = i

        #append DataFrame to list
        all_df.append(temp_df)

    #concatenate all DataFrame's
    all_df = pd.concat([i for i in all_df])

    #reset index
    all_df.reset_index(drop=False,inplace=True)

    #column labels
    all_df.columns = ['word','count','genre']

    # in order to have a single root node add 'all genres'
    all_df["all genres"] = "all genres" 

    #create plotly treemap figure
    fig = px.treemap(all_df, path=['all genres', 'genre', 'word'], values='count',)
    
    #title parameters
    title_param = dict(text='<b>Most Common Nouns, by genre</b><br>spaCy used for classifying PoS</b>', 
                        font=dict(size=20))
    
    #update layout
    fig.update_layout(title=title_param,
                    font= dict(family='Helvetica',size=10),
                    width=900,
                    height=900,
                    autosize=False,
                    margin=dict(l=40,r=40,b=85,t=100,pad=0,))
        
    #show plot
    fig.show()
    
    return fig

# %%
fig_nouns = genreMap(df,'nouns')
# Out:
# <div>
#
#
#             <div id="721f4e42-0c31-4c74-8b13-e010687ab16d" class="plotly-graph-div" style="height:900px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("721f4e42-0c31-4c74-8b13-e010687ab16d")) {
#                     Plotly.newPlot(
#                         '721f4e42-0c31-4c74-8b13-e010687ab16d',
#                         [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["all genres/hip-hop/rap/air", "all genres/metal/air", "all genres/pop/air", "all genres/soul/air", "all genres/alternative/arms", "all genres/pop/rock/arms", "all genres/soul/arms", "all genres/hip-hop/rap/ass", "all genres/pop/babe", "all genres/alternative/baby", "all genres/hip-hop/rap/baby", "all genres/pop/baby", "all genres/pop/rock/baby", "all genres/punk/baby", "all genres/rock/baby", "all genres/soul/baby", "all genres/hip-hop/rap/bag", "all genres/hip-hop/rap/ball", "all genres/rock/ball", "all genres/pop/band", "all genres/punk/band", "all genres/rock/band", "all genres/rock/bar", "all genres/pop/rock/beach", "all genres/hip-hop/rap/beat", "all genres/punk/beat", "all genres/death-metal/beauty", "all genres/alternative/bed", "all genres/pop/rock/bed", "all genres/rock/bed", "all genres/pop/rock/birds", "all genres/alternative/bit", "all genres/punk/bit", "all genres/hip-hop/rap/bitch", "all genres/pop/bitch", "all genres/hip-hop/rap/bitches", "all genres/death-metal/blade", "all genres/punk/blitzkrieg", "all genres/hip-hop/rap/block", "all genres/alternative/blood", "all genres/death-metal/blood", "all genres/metal/blood", "all genres/pop/blood", "all genres/pop/rock/blood", "all genres/punk/blood", "all genres/rock/blood", "all genres/death-metal/bodies", "all genres/metal/bodies", "all genres/alternative/body", "all genres/death-metal/body", "all genres/hip-hop/rap/body", "all genres/metal/body", "all genres/pop/body", "all genres/pop/rock/body", "all genres/punk/body", "all genres/rock/body", "all genres/soul/body", "all genres/death-metal/bone", "all genres/death-metal/bones", "all genres/metal/bones", "all genres/punk/bop", "all genres/alternative/boy", "all genres/hip-hop/rap/boy", "all genres/pop/boy", "all genres/pop/rock/boy", "all genres/punk/boy", "all genres/rock/boy", "all genres/soul/boy", "all genres/hip-hop/rap/boys", "all genres/punk/boys", "all genres/rock/boys", "all genres/death-metal/brain", "all genres/metal/brain", "all genres/death-metal/brains", "all genres/punk/brand", "all genres/alternative/breath", "all genres/death-metal/breath", "all genres/metal/breath", "all genres/pop/rock/breath", "all genres/soul/breath", "all genres/hip-hop/rap/brother", "all genres/punk/brother", "all genres/hip-hop/rap/brothers", "all genres/punk/bus", "all genres/hip-hop/rap/business", "all genres/hip-hop/rap/car", "all genres/pop/rock/car", "all genres/rock/car", "all genres/soul/case", "all genres/death-metal/casket", "all genres/hip-hop/rap/chain", "all genres/alternative/chance", "all genres/metal/chance", "all genres/pop/chance", "all genres/pop/rock/chance", "all genres/rock/chance", "all genres/soul/chance", "all genres/metal/child", "all genres/rock/child", "all genres/soul/child", "all genres/metal/children", "all genres/soul/children", "all genres/hip-hop/rap/city", "all genres/pop/rock/city", "all genres/punk/city", "all genres/soul/city", "all genres/punk/clock", "all genres/hip-hop/rap/clothes", "all genres/punk/clothes", "all genres/hip-hop/rap/club", "all genres/hip-hop/rap/comin", "all genres/punk/company", "all genres/alternative/control", "all genres/metal/control", "all genres/pop/rock/control", "all genres/rock/control", "all genres/soul/control", "all genres/pop/rock/corner", "all genres/death-metal/corpse", "all genres/punk/country", "all genres/hip-hop/rap/couple", "all genres/alternative/crowd", "all genres/alternative/daddy", "all genres/punk/daddy", "all genres/pop/dance", "all genres/pop/rock/dark", "all genres/soul/dark", "all genres/death-metal/darkness", "all genres/metal/darkness", "all genres/pop/rock/darkness", "all genres/pop/darling", "all genres/death-metal/dawn", "all genres/metal/dawn", "all genres/alternative/day", "all genres/death-metal/day", "all genres/hip-hop/rap/d ...

# %% [markdown]
# # Load Universal Sentence Encoder

# %% [markdown]
# In order to get embeddings - we need to load the universal sentence encoder.

# %%
#get universal sentence encoder
USE = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# %%
def getUSEEmbed(_string,USE = USE):
    
    """Function takes a string argument and returns its high dimensional vector from USE"""
    
    return np.array(USE([_string])[0])

# %%
example = getUSEEmbed('Hello how are you?')

# %% [markdown]
# Inspect shape of the vector

# %%
example.shape
# Out:
# (512,)

# %% [markdown]
# We can assess similarity by looking at **cosine similarity** of the vectors..
#
# The cosine similarity of two high dimensional vectors representing SIMILAR sentences should be high..
#
# For sentences that are DIFFERENT, the cosine similarity should be low..

# %%
#some example sentences
example_sentences = ["The weather is going to be really warm today",
                     
                     "Today is going to be the sunniest day of the year",
                     
                     "I like my eggs sunny side up",
                     
                     "Breakfast is my favourite meal"]

# %%
#get embeddings for each example sentence
embed = [getUSEEmbed(i) for i in example_sentences]

# %%
#set up a dictionary where each sentece is a key and its value is its 512 vector embedding
dic_ = dict(zip(test,embed))

# %%
#let's find all the unique pairwise sentence combinations
combo = [list(i) for i in itertools.combinations(example_sentences, 2)]

# %%
combo
# Out:
# [['The weather is going to be really warm today',
#   'Today is going to be the sunniest day of the year'],
#  ['The weather is going to be really warm today',
#   'I like my eggs sunny side up'],
#  ['The weather is going to be really warm today',
#   'Breakfast is my favourite meal'],
#  ['Today is going to be the sunniest day of the year',
#   'I like my eggs sunny side up'],
#  ['Today is going to be the sunniest day of the year',
#   'Breakfast is my favourite meal'],
#  ['I like my eggs sunny side up', 'Breakfast is my favourite meal']]

# %%
def cosineSimilarity(vec_x,vec_y):
    
    """Function returns pairwise cosine similarity of two vector arguments"""
    
    return cosine_similarity([vec_x],[vec_y])[0][0]

# %% [markdown]
# Let's make a DataFrame that maps the cosine similarity for each unique sentence pair

# %%
#empty list for data
cs = []

#lop through each unique sentence pairing
for i in range(len(combo)):
    
    #get cosine similarity for each
    cs_ = cosineSimilarity(dic_[combo[i][0]],dic_[combo[i][1]])
    
    #append data to list
    cs.append((combo[i][0],combo[i][1],cs_))

# %%
#construct DataFrame
cs_df = pd.DataFrame(cs,columns=['sent_1','sent_2','cosine_similarity']).\
                    sort_values(by='cosine_similarity',ascending=False)

# %% [markdown]
# Let's look at the data..

# %% [markdown]
# Sentences that are similar have higher cosine similarity. This mean the vectors that represent these sentences are similar. That's really impressive!

# %%
cs_df
# Out:
#                                               sent_1  \
# 0       The weather is going to be really warm today
# 5                       I like my eggs sunny side up
# 1       The weather is going to be really warm today
# 3  Today is going to be the sunniest day of the year
# 2       The weather is going to be really warm today
# 4  Today is going to be the sunniest day of the year
#
#                                               sent_2  cosine_similarity
# 0  Today is going to be the sunniest day of the year           0.519781
# 5                     Breakfast is my favourite meal           0.416550
# 1                       I like my eggs sunny side up           0.150719
# 3                       I like my eggs sunny side up           0.146834
# 2                     Breakfast is my favourite meal           0.139814
# 4                     Breakfast is my favourite meal           0.137269

# %% [markdown]
# # USE Embeddings

# %% [markdown]
# Let's apply this technique to get embeddings for each of our songs.

# %%
#get USE embeddings for each song
df_embed = pd.DataFrame([getUSEEmbed(df.lyrics[i]) for i in range(df.shape[0])],\
                        index=[df.song[i] for i in range(df.shape[0])])

# Onda diferente feat Papatinho  0.058184  0.046278 -0.058671 -0.058950
# Young Wild Free               -0.053104  0.017477 -0.062313 -0.047047
# Gin Juice                      0.013241 -0.002306 -0.059803 -0.060226
# Bitch Please                   0.026785 -0.035045 -0.058133 -0.058393
# Be Nice                       -0.026362  0.031555 -0.071270  0.008813
# A Word Witchya intro          -0.006267 -0.041129 -0.057270 -0.020249
# Wiggle                        -0.032604  0.021993 -0.058705 -0.024573
# Let It Go Feat Snoop Dogg     -0.007739 -0.065296 -0.063339 -0.065947
# B Please II                    0.022267  0.007700 -0.061325 -0.061239
# California Gurls               0.055585 -0.031728 -0.054001 -0.054493
# Drop It Like It s Hot         -0.020529 -0.017223 -0.060762 -0.057121
# Professional Rapper           -0.021357  0.005218 -0.059383 -0.040417
# All I Do Is Win                0.046428  0.023273 -0.063937 -0.061900
# Nuthin but a G Thang          -0.014550 -0.038616 -0.062715 -0.053229
#
# [20 rows x 512 columns]

# %% [markdown]
# Let's use another data reduction technique - Principal Component Analysis, to reduce the dimensionality of these embeddings.

# %%
def getPCA(df,df_embedding,n_components):
    
    """Function uses PCA to reduce dimensionality of the USE embeddings for each song
    returning a DataFrame with either 1,2,3 PC's"""
    
    cols = df_embedding.index
    
    embeddings = df_embedding.iloc[:, 1:] #subset on embeddings only
    
    pca = PCA(n_components=n_components) #instantiate PCA

    pca.fit(embeddings) #fit the embeddings

    new_values = pca.transform(embeddings) #transform / reduce data
    
    #let's see how much variance can be explained
    print(pca.explained_variance_ratio_.cumsum()) 
    
    #option to have 1,2 columns / components
    if n_components == 2:
        
        columns = ['pca_x','pca_y']
        
    elif n_components == 3:
        
        columns = ['pca_x','pca_y','pca_z']
        
    else: 
        columns = ['pc']
    
    df_reduced = pd.DataFrame(new_values,index=cols) #get new DataFrame
    
    df_reduced.columns = columns
    
    if n_components == 1:
        
        df_reduced.sort_values(by='pc',ascending=False,inplace=True)
    
    #merges PCA DataFrame on original DataFrame
    df_merge = pd.merge(df,df_reduced,how='inner',left_on='song',right_on=df_reduced.index)
    
    return df_merge #returns merged DataFrame

# %%
pc_1 = getPCA(df,df_embed,n_components=1)
pc_2 = getPCA(df,df_embed,n_components=2)
pc_3 = getPCA(df,df_embed,n_components=3)
# Out:
# [0.06896908]
# [0.06896908 0.11355067]
# [0.06896908 0.11355067 0.1463629 ]

# %% [markdown]
# Let's inspect the data..

# %%
#look at the 1st principal component 
pc_1.head(2)
# Out:
#        artist                song  \
# 0  Snoop Dogg           Hollywood
# 1  Snoop Dogg  I Wanna Go Outside
#
#                                               lyrics        genre  \
# 0  where the beautiful people at? i said where th...  hip-hop/rap
# 1  yes and we are back here at the jack-off hour ...  hip-hop/rap
#
#    lyric_count  lyric_count_norm  artist_coding  genre_coding  \
# 0          302         10.234134              0             0
# 1          428         14.504005              0             0
#
#                                                nouns  \
# 0  vibe gorilla hills city people bitches thing j...
# 1  dial nigga sky tension battles hands kitchen o...
#
#                                                verbs  \
# 0  dimmed clap tie wake excite sinking going make...
# 1  supposed get take waitin rush dance say stuck ...
#
#                                           adjectives  \
# 0  alright seductive wonderful bad dark real frag...
# 1  double o fresh old whole right little safe rea...
#
#                                              adverbs        pc
# 0  now so where exactly how just bareback never back  0.082787
# 1  out around outside rather wisely too right how... -0.181245

# %%
#look at the 1st and 2nd principal components
pc_2.head(2)
# Out:
#        artist                song  \
# 0  Snoop Dogg           Hollywood
# 1  Snoop Dogg  I Wanna Go Outside
#
#                                               lyrics        genre  \
# 0  where the beautiful people at? i said where th...  hip-hop/rap
# 1  yes and we are back here at the jack-off hour ...  hip-hop/rap
#
#    lyric_count  lyric_count_norm  artist_coding  genre_coding  \
# 0          302         10.234134              0             0
# 1          428         14.504005              0             0
#
#                                                nouns  \
# 0  vibe gorilla hills city people bitches thing j...
# 1  dial nigga sky tension battles hands kitchen o...
#
#                                                verbs  \
# 0  dimmed clap tie wake excite sinking going make...
# 1  supposed get take waitin rush dance say stuck ...
#
#                                           adjectives  \
# 0  alright seductive wonderful bad dark real frag...
# 1  double o fresh old whole right little safe rea...
#
#                                              adverbs     pca_x     pca_y
# 0  now so where exactly how just bareback never back  0.082787  0.263123
# 1  out around outside rather wisely too right how... -0.181244  0.356239

# %%
#look at the 1st, 2nd and 3rd principal components
pc_3.head(2)
# Out:
#        artist                song  \
# 0  Snoop Dogg           Hollywood
# 1  Snoop Dogg  I Wanna Go Outside
#
#                                               lyrics        genre  \
# 0  where the beautiful people at? i said where th...  hip-hop/rap
# 1  yes and we are back here at the jack-off hour ...  hip-hop/rap
#
#    lyric_count  lyric_count_norm  artist_coding  genre_coding  \
# 0          302         10.234134              0             0
# 1          428         14.504005              0             0
#
#                                                nouns  \
# 0  vibe gorilla hills city people bitches thing j...
# 1  dial nigga sky tension battles hands kitchen o...
#
#                                                verbs  \
# 0  dimmed clap tie wake excite sinking going make...
# 1  supposed get take waitin rush dance say stuck ...
#
#                                           adjectives  \
# 0  alright seductive wonderful bad dark real frag...
# 1  double o fresh old whole right little safe rea...
#
#                                              adverbs     pca_x     pca_y  \
# 0  now so where exactly how just bareback never back  0.082787  0.263122
# 1  out around outside rather wisely too right how... -0.181244  0.356235
#
#       pca_z
# 0  0.096147
# 1  0.058101

# %% [markdown]
# Let's do some grouping to explore which artists have lyrics that are most similar to each other

# %% [markdown]
# As we can see - even with one component, artists from genres tend to cluster together. Death metal, heavy metal and rock differ slighty from one another but vastly different to pop and soul. This makes sense!

# %%
pc1_group = pd.DataFrame(pc_1.groupby('artist')['pc'].mean())

fig = pc1_group.sort_values(by='pc').plot.barh(labels=dict(variable="artist", value="PC"),
                               template='ggplot2')

title_param = dict(text='<b>Lyric similarity, by artist</b><br>Based on Principal Component 1</b>', 
                        font=dict(size=20))

margin_param=dict(l=40,r=40,b=85,t=200,pad=0)

fig.update_layout(
                      title=title_param,
                      width=1000,
                      height=1000,
                    margin = margin_param,
                      xaxis = dict(title='Principal Component 1'),
                      autosize=False,
                      showlegend=False,
                    )
# Out:
# <div>
#
#
#             <div id="8ffd0473-daf5-4245-9be7-27ef29118237" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8ffd0473-daf5-4245-9be7-27ef29118237")) {
#                     Plotly.newPlot(
#                         '8ffd0473-daf5-4245-9be7-27ef29118237',
#                         [{"alignmentgroup": "True", "hovertemplate": "artist=%{y}<br>PC=%{x}<extra></extra>", "legendgroup": "pc", "marker": {"color": "#F8766D"}, "name": "pc", "offsetgroup": "pc", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [-0.30372498014069893, -0.27351581999110286, -0.22257232537428998, -0.18598112122489258, -0.16779944833706095, -0.1627622085084054, -0.15537368162843213, -0.15515738876231344, -0.15355476234408721, -0.14232969483482158, -0.1343431307984547, -0.12011799558722304, -0.11703400342164758, -0.10953994513331251, -0.10227963783536632, -0.0941940801964749, -0.09392539241587179, -0.07381970134330543, -0.06673560203217953, -0.06559993032412358, -0.053328649725693844, -0.053080041306538275, -0.04905759566257917, -0.0353353434160213, -0.015493062163477473, -0.009071699735608618, -0.008731073176065958, -0.004648928627731875, 0.004989338029839838, 0.008180813855875874, 0.015623235762170515, 0.019877061786725558, 0.026098803179956935, 0.026598537072161872, 0.04670770656557545, 0.054403570057675724, 0.08083374136982188, 0.08832437318098808, 0.08939429333895178, 0.11128383057130027, 0.11842795403625547, 0.1645529202573882, 0.1677546406980312, 0.17948798302493568, 0.1924086456945091, 0.23251338850446213, 0.2569919563622937, 0.26934557842227175, 0.36612692206333, 0.3766710538715905, 0.449046950022635, 0.4581133588504026], "xaxis": "x", "y": ["Lionel Richie", "Luther Vandross", "Maroon 5", "George Michael", "Adele", "Sam Smith", "Michael Jackson", "Aretha Franklin", "Marvin Gaye", "Selena Gomez", "Stevie Wonder", "Madonna", "The Beatles", "Iggy and The Stooges", "Drake", "Bon Jovi", "Lady Gaga", "Taylor Swift", "U2", "Queen", "Stone Temple Pilots", "Elton John", "The Rolling Stones", "Red Hot Chili Peppers", "Coldplay", "Stormzy", "JAY Z", "Motley Crue", "Snoop Dogg", "Nine Inch Nails", "Ramones", "Kanye West", "Pearl Jam", "AC DC", "Sex Pistols", "Alice In Chains", "Nirvana", "The Clash", "Green Day", "Metallica", "Black Sabbath", "Public Enemy", "Iron Maiden", "Judas Priest", "Anthrax", "Megadeth", "Death", "Cradle of Filth", "Slayer", "Carcass", "Cannibal Corpse", "Exhumed"], "yaxis": "y"}],
#                         {"autosize": false, "barmode": "relative", "height": 1000, "legend": {"title": {"text": "artist"}, "tracegroupgap": 0}, "margin": {"b": 85, "l": 40, "pad": 0, "r": 40, "t": 200}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "rgb(51,51,51)"}, "error_y": {"color": "rgb(51,51,51)"}, "marker": {"line": {"color": "rgb(237,237,237)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(237,237,237)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(51,51,51)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(51,51,51)"}, "baxis": {"endlinecolor": "rgb(51,51,51)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(51,51,51)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {"outlinewid ...

# %% [markdown]
#  Let's look at the same analysis but grouped by genres.

# %% [markdown]
# This confirms what we found above, the lyrics in genres cluster into groups that make sense.

# %%
pc1_group = pd.DataFrame(pc_1.groupby('genre')['pc'].mean())

fig = pc1_group.sort_values(by='pc').plot.bar(labels=dict(variable="genre", value="PC"),\
                               template='ggplot2')

title_param = dict(text='<b>Lyric similarity, by genre</b><br>Based on Principal Component 1</b>', 
                        font=dict(size=20))

margin_param=dict(l=40,r=40,b=85,t=200,pad=0)

fig.update_layout(
                      title=title_param,
                      width=1000,
                      height=900,
                    margin=margin_param,
                      xaxis = dict(title='Genre'),
                      yaxis = dict(title='Principal Component 1'),
                      autosize=False,
                      showlegend=False,
                    )
# Out:
# <div>
#
#
#             <div id="e15868d9-0bda-4b49-84ab-e7b3ea0b341a" class="plotly-graph-div" style="height:900px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e15868d9-0bda-4b49-84ab-e7b3ea0b341a")) {
#                     Plotly.newPlot(
#                         'e15868d9-0bda-4b49-84ab-e7b3ea0b341a',
#                         [{"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>PC=%{y}<extra></extra>", "legendgroup": "pc", "marker": {"color": "#F8766D"}, "name": "pc", "offsetgroup": "pc", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["soul", "pop", "pop/rock", "rock", "hip-hop/rap", "alternative", "punk", "metal", "death-metal"], "xaxis": "x", "y": [-0.1840921406497818, -0.1158224671468346, -0.09187648363488825, -0.039679064167598546, -0.010346763501674863, 0.02898591310786143, 0.04908063066509428, 0.19903397005371698, 0.3640043217868361], "yaxis": "y"}],
#                         {"autosize": false, "barmode": "relative", "height": 900, "legend": {"title": {"text": "genre"}, "tracegroupgap": 0}, "margin": {"b": 85, "l": 40, "pad": 0, "r": 40, "t": 200}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "rgb(51,51,51)"}, "error_y": {"color": "rgb(51,51,51)"}, "marker": {"line": {"color": "rgb(237,237,237)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(237,237,237)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(51,51,51)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(51,51,51)"}, "baxis": {"endlinecolor": "rgb(51,51,51)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(51,51,51)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {"outlinewidth ...

# %% [markdown]
# Let's make a more sophisticated visualisation that uses scatter plots to show this data by song.
#
# We can look at this in two dimensions (PC1,PC2) but also in three dimensions (PC1,PC2,PC3)

# %% [markdown]
# # Plotting

# %%
def scatPlot(df,df_embed,n_components=2):
    
    """Comprehensive function that adds components to a scatter plot"""
    
    df = getPCA(df,df_embed,n_components) #gets PCA
             
    fig = go.Figure() #instantiate Ploty.go object

    genres = df.genre.unique() #get unique genres     
    
    for i in range(len(genres)): #loop through genres

        df_mask = df[df.genre == genres[i]] #subset on genre
        
        df_mask['artist_song'] = df_mask['artist']+' // '+df_mask['song'] #new labels for traces
             
        if n_components == 2:
            
            #add traces for 2d - several formatting options for hover text, and marker size
            fig.add_trace(go.Scatter(
                          x=df_mask['pca_x'],
                          y=df_mask['pca_y'],
                          name=genres[i],
                          text=df_mask['artist_song'],
                          mode='markers',hoverinfo='text',
                          marker={'size':df_mask.lyric_count_norm}))
        
        else:
            #add traces for 3d - several formatting options for hover text, and marker size
            fig.add_trace(go.Scatter3d(
                          x=df_mask['pca_x'],
                          y=df_mask['pca_y'],
                          z=df_mask['pca_z'],
                          name=genres[i],
                          text=df_mask['artist_song'],
                          mode='markers',hoverinfo='text',
                          marker={'size':df_mask.lyric_count_norm}))
    # axis parameters
    axis_x_param=dict(showline=True, 
                      zeroline=True,
                      showgrid=True,
                      showticklabels=True,
                      title='Principal Component 1')
    # axis parameters
    axis_y_param=dict(showline=True, 
                      zeroline=True,
                      showgrid=True,
                      showticklabels=True,
                      title='Principal Component 2')
    
    # legend parameters
    legend_param= dict(bgcolor=None,
                       bordercolor = None,
                       borderwidth = None,
                       font = dict(family='Open Sans',size=15,color=None),
                       orientation='h',
                       itemsizing='constant',
                       title=dict(text='Genres (clickable!)',
                                  font=dict(family='Open Sans',size=20,color=None),
                                  side='top'),)
    # margin parameters
    margin_param=dict(l=40,r=40,b=85,t=200,pad=0)
    
    # title parameters
    title_param = dict(text='<b>Similarities and differences in song lyrics by genre</b>\
    <br>Universal sentence encodings and dimensionality reduction</b><br>Scatter size represents lyric count', 
                        font=dict(size=20))
    
    #update layout
    fig.update_layout(legend= legend_param,
                      title=title_param,
                      width=1000,
                      height=1000,
                      autosize=False,
                      showlegend=True,
                      xaxis=axis_x_param,
                      yaxis=axis_y_param,
                      margin=margin_param,)
    
        


    fig.show()    
    return fig

# %%
scatPlot_2 = scatPlot(df,df_embed,n_components=2)
# Out:
# [0.06896908 0.11355067]
# <div>
#
#
#             <div id="d5fa9d43-f784-4b4b-97c4-7c01a8e02a61" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d5fa9d43-f784-4b4b-97c4-7c01a8e02a61")) {
#                     Plotly.newPlot(
#                         'd5fa9d43-f784-4b4b-97c4-7c01a8e02a61',
#                         [{"hoverinfo": "text", "marker": {"size": [10.234134319162045, 14.504004929143562, 25.00924214417745, 24.77202711028959, 14.30067775723968, 19.485520640788664, 7.997535428219347, 13.961799137399876, 18.943314849044977, 21.68823166974738, 10.200246457178066, 4.507085643869378, 11.759088108441158, 8.912507701786813, 26.093653727664815, 9.69192852741836, 17.452248921749845, 55.0, 16.401725200246457, 24.229821318545902, 8.743068391866913, 15.046210720887247, 18.875539125077015, 14.673444239063464, 9.48860135551448, 8.133086876155268, 9.048059149722736, 29.414664202094887, 18.604436229205177, 14.944547134935306, 14.944547134935306, 10.064695009242145, 14.029574861367838, 26.161429451632777, 9.217498459642638, 17.79112754158965, 16.401725200246457, 28.025261860751694, 11.284658040665434, 11.047443006777574, 14.673444239063464, 17.655576093653725, 7.692544670363525, 9.658040665434381, 21.925446703635245, 10.606900800985828, 12.199630314232902, 6.167590881084411, 5.117067159581023, 16.605052372150336, 17.011706715958102, 13.351817621688232, 13.046826863832408, 9.75970425138632, 11.013555144793592, 12.538508934072706, 6.032039433148491, 0.33887861983980283, 13.927911275415896, 20.163277880468268, 12.301293900184843, 11.725200246457177, 21.722119531731362, 7.048675292667898, 14.978434996919285, 10.81022797288971, 38.69993838570548, 28.059149722735675, 15.69008009858287, 13.656808379544053, 3.7615526802218118, 13.758471965495994, 18.875539125077015, 14.232902033271719, 10.674676524953789, 10.166358595194085, 19.485520640788664, 6.269254467036353, 10.132470733210104, 12.233518176216881, 6.099815157116451, 13.724584103512015, 26.940850277264325, 23.585951940850276, 12.335181762168823, 11.92852741836106, 23.78927911275416, 32.972889710412815, 22.027110289587185, 19.28219346888478, 20.23105360443623, 14.707332101047443, 11.047443006777574, 18.16389402341343, 15.38508934072705, 13.792359827479974, 22.73875539125077, 20.705483672211955, 20.50215650030807, 23.077634011090574, 11.352433764633394, 15.961182994454713, 29.516327788046823, 17.11337030191004, 16.537276648182377, 22.50154035736291, 20.12939001848429, 16.5033887861984, 32
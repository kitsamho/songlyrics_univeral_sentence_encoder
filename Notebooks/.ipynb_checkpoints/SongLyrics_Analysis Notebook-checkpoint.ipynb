# %% [markdown]
# # Analyzing lyrics from different music genres with universal sentence encoding

# %% [markdown]
# Applying Google’s Universal Sentence Encoder and Principal Component Analysis to identify similarities and differences across music genres
#
# ---

# %% [markdown]
# <img src="../assets/header.jpeg" style="width: 400px;">

# %% [markdown]
# # Project Aim
# There are differences between the lyrics of different genres and we can quantify and measure this!
#
# ---
#
#
#
#
# ## Where do we get the data?
#  - We will scrape lyrics from Musixmatch.com, a free website that hosts a tonne of accurate lyric content
#
# ## What kind of method/metric will allow us to quantify lyrical diversity in an intuitive way?
# - We will represent lyrics using high dimensional vectors from Google’s Universal Sentence Encoder
# - We will apply Principal Component Analysis (PCA) to reduce these high dimensional representations to n=1,2,3 dimensions
#
# ## How can we visualize this in a meaningful way?
# - We will use Plotly and build a combination of simple plots and more sophisticated 2d and 3d scatter plots to see where there are similarities and differences in lyrics

# %% [markdown]
# # Libraries

# %%
#data / numbers
import pandas as pd
pd.options.plotting.backend = "plotly"
import numpy as np
import string
import itertools

#NLP
import spacy

#Tensorflow / Sentence Encoding
import tensorflow as tf
import tensorflow_hub as hub

#sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS 

#PCA
from sklearn.decomposition import PCA
import contractions as ct

#viz
import plotly
import plotly.graph_objs as go
import plotly.express as px

from plotly.offline import download_plotlyjs, iplot, plot
import chart_studio
import plotly.figure_factory as ff
import chart_studio.plotly as py

# %%
chart_studio.tools.set_credentials_file(username='kitsamho', api_key='JPuAu5Xtf7BhX43kDd4m')

# %% [markdown]
# ## Helper Functions

# %%
chart_studio.tools.set_credentials_file(username='<USER NAME HERE>', api_key='<API KEY HERE>')

def savePlot(fig,filename):
        
    """Method to save Plotly figure to chart studio. Ensure you include your user and API key"""

    py.plot(fig, filename = filename, auto_open=True) #save Plotly figure to Chart Studio

    return print('Successfully saved as ',filename)

# %% [markdown]
# ### Read in data..

# %%
df = pd.read_csv('../Lyric_data/lyrics.csv') #read in csv

# %% [markdown]
# ### Get Genre Dictionary

# %%
#get DataFrame of unique artists
df_art_unique = df.drop_duplicates(subset='artist',keep='first')

# %%
#subset on artist and genre columns
df_art_unique = df_art_unique[['artist','genre']]

# %%
#make a genre dictionary
genre_dic = dict(zip(df_art_unique.artist,df_art_unique.genre))

# %%
genre_dic
# Out:
# {'Katy Perry': 'pop',
#  'Ed Sheeran': 'pop',
#  'Billie Eilish': 'pop',
#  'Dua Lipa': 'pop',
#  'Meshuggah': 'death-metal',
#  'Deicide': 'death-metal',
#  'Dismember': 'death-metal',
#  'Children of Bodom': 'death-metal',
#  'Immolation': 'death-metal',
#  'Napalm Death': 'death-metal',
#  'Decapitated': 'death-metal',
#  'The Black Dahlia Murder': 'death-metal',
#  'Obscura': 'death-metal',
#  'Nile': 'death-metal',
#  'Cryptopsy': 'death-metal',
#  'Autopsy': 'death-metal',
#  'Hypocrisy': 'death-metal',
#  'Led Zeppelin': 'rock',
#  'Rush': 'rock',
#  'Kings of Leon': 'rock',
#  'INXS': 'rock',
#  'Eagles': 'rock',
#  'Ray Charles': 'r&b/soul',
#  'Al Green': 'r&b/soul',
#  'Smokey Robinson': 'r&b/soul',
#  'James Brown': 'r&b/soul',
#  'The Righteous Brothers': 'r&b/soul',
#  'Snoop Dogg': 'hip-hop/rap',
#  'Cannibal Corpse': 'death-metal',
#  'Kanye West': 'hip-hop/rap',
#  'Nine Inch Nails': 'alternative',
#  'AC DC': 'rock',
#  'The Rolling Stones': 'rock',
#  'Public Enemy': 'hip-hop/rap',
#  'Alice In Chains': 'alternative',
#  'Cradle of Filth': 'death-metal',
#  'Metallica': 'metal',
#  'The Beatles': 'pop',
#  'Slayer': 'metal',
#  'Adele': 'r&b/soul',
#  'JAY Z': 'hip-hop/rap',
#  'Nirvana': 'alternative',
#  'Motley Crue': 'rock',
#  'Stevie Wonder': 'r&b/soul',
#  'Sex Pistols': 'punk',
#  'Elton John': 'pop',
#  'Queen': 'rock',
#  'Stormzy': 'hip-hop/rap',
#  'Megadeth': 'metal',
#  'Madonna': 'pop',
#  'U2': 'pop/rock',
#  'Drake': 'hip-hop/rap',
#  'Coldplay': 'pop/rock',
#  'Pearl Jam': 'alternative',
#  'Stone Temple Pilots': 'alternative',
#  'Bon Jovi': 'rock',
#  'Iron Maiden': 'metal',
#  'Black Sabbath': 'metal',
#  'Judas Priest': 'metal',
#  'Michael Jackson': 'pop',
#  'Taylor Swift': 'pop',
#  'Lady Gaga': 'pop',
#  'Maroon 5': 'pop/rock',
#  'Sam Smith': 'r&b/soul',
#  'Marvin Gaye': 'r&b/soul',
#  'Luther Vandross': 'r&b/soul',
#  'Lionel Richie': 'r&b/soul',
#  'Carcass': 'death-metal',
#  'Death': 'death-metal',
#  'Exhumed': 'death-metal',
#  'Ramones': 'punk',
#  'The Clash': 'punk',
#  'Iggy and The Stooges': 'punk',
#  'Selena Gomez': 'pop',
#  'Anthrax': 'metal',
#  'Red Hot Chili Peppers': 'alternative',
#  'George Michael': 'pop',
#  'Aretha Franklin': 'r&b/soul',
#  'Foo Fighters': 'alternative',
#  'Radiohead': 'alternative',
#  'Soundgarden': 'alternative',
#  'The Smashing Pumpkins': 'alternative',
#  'Morbid Angel': 'death-metal',
#  'Suffocation': 'death-metal',
#  'At the Gates': 'death-metal',
#  'Obituary': 'death-metal',
#  'Mayhem': 'death-metal',
#  'Behemoth': 'death-metal',
#  'Aerosmith': 'rock',
#  'Scorpions': 'rock',
#  'Genesis': 'rock',
#  'Tupac': 'hip-hop/rap',
#  'Eminem': 'hip-hop/rap',
#  'Wu Tang Clan': 'hip-hop/rap',
#  'Beastie Boys': 'hip-hop/rap',
#  'Nas': 'hip-hop/rap',
#  'The Notorious B I G': 'hip-hop/rap',
#  'Oasis': 'pop/rock',
#  'Blur': 'pop/rock',
#  'The Stone Roses': 'pop/rock',
#  'OneRepublic': 'pop/rock',
#  'Imagine Dragons': 'pop/rock',
#  'The Script': 'pop/rock',
#  'Goo Goo Dolls': 'pop/rock',
#  'The Jam': 'punk',
#  'Black Flag': 'punk',
#  'Dead Kennedys': 'punk',
#  'Rancid': 'punk',
#  'The Offspring': 'punk',
#  'Buzzcocks': 'punk',
#  'Discharge': 'punk',
#  'Testament': 'metal',
#  'Machine Head': 'metal',
#  'Green Day': 'punk',
#  'Social Distortion': 'punk',
#  'Bad Brains': 'punk',
#  'NOFX': 'punk',
#  'Lagwagon': 'punk',
#  'blink 182': 'punk',
#  'Sum 41': 'punk',
#  'Mary J Blige': 'r&b/soul',
#  'Bill Withers': 'r&b/soul',
#  'Alicia Keys': 'r&b/soul'}

# %% [markdown]
# ### Count word frequencies for each song

# %%
#get lyric frequencies for each song
df['lyric_count'] = df['lyrics'].map(lambda x: len(x.split()))

# %% [markdown]
# For plotting, we need to scale back the data in order for the traces to be the right size for the Plotly visualisations

# %%
#normalise lyric counts
norm = [float(i)/max(df.lyric_count) for i in df.lyric_count]

# %%
#get column for normalised data
df['lyric_count_norm'] = norm

# %%
#scale it up
df['lyric_count_norm'] = df['lyric_count_norm'].map(lambda x: x*55)

# %% [markdown]
# Let's look at what we have..

# %%
df.head(3)
# Out:
#        artist                            song  \
# 0  Katy Perry  The One That Got Away acoustic
# 1  Katy Perry             Who Am I Living For
# 2  Katy Perry                         Daisies
#
#                                               lyrics genre  lyric_count  \
# 0  summer after high school, when we first met we...   pop          221
# 1  yeah, yeah, yeah i can feel a phoenix inside o...   pop          190
# 2  told them your dreams and they all started lau...   pop          157
#
#    lyric_count_norm
# 0          7.489217
# 1          6.438694
# 2          5.320394

# %% [markdown]
# ### Get a unique artist code (for plotting)

# %% [markdown]
# We need to get some unique codes in order to be able to colour our traces

# %%
#get a unique code for each artists
artist_code = [i for i in range(len(df.artist.unique()))]

#get a dictionary
artist_dic = dict(zip(df.artist.unique(),artist_code))

#add artist code as column
df['artist_coding'] = df.artist.map(lambda x: artist_dic[x])

# %% [markdown]
# ### Get a genre code (for plotting)

# %% [markdown]
# As above - but for genre

# %%
#get a unique code for each genre
genre_code = [i for i in range(len(df.genre.unique()))]

#get a dictionary
genre_code_dic = dict(zip(df.genre.unique(),genre_code))

#add genre code as column
df['genre_coding'] = df.genre.map(lambda x: genre_code_dic[x])

# %% [markdown]
# Let's look at what we have..

# %%
df.head(3)
# Out:
#        artist                            song  \
# 0  Katy Perry  The One That Got Away acoustic
# 1  Katy Perry             Who Am I Living For
# 2  Katy Perry                         Daisies
#
#                                               lyrics genre  lyric_count  \
# 0  summer after high school, when we first met we...   pop          221
# 1  yeah, yeah, yeah i can feel a phoenix inside o...   pop          190
# 2  told them your dreams and they all started lau...   pop          157
#
#    lyric_count_norm  artist_coding  genre_coding
# 0          7.489217              0             0
# 1          6.438694              0             0
# 2          5.320394              0             0

# %% [markdown]
# # EDA

# %% [markdown]
# Before we start looking at sentence embeddings, let's have a little explore of what data we have

# %% [markdown]
# ## Count of Genre

# %%
#plot genres
fig_genre = pd.DataFrame(df.genre.value_counts()).plot.barh(template='ggplot2')

#title parameters
title_param = dict(text='<b>Count of Genre</b><br></b>', 
                        font=dict(size=15))
#margin parameters
margin_param=dict(l=25,r=25,b=50,t=50,pad=0)

#update layout
fig_genre.update_layout(title=title_param,
                        margin = margin_param,
                        width=480,
                        height=500,        
                        xaxis = dict(title_text='Count',title_font = dict(size=10),tickfont=dict(size=10)),
                        yaxis = dict(title_text='Genre',title_font = dict(size=10),tickfont=dict(size=10)))

#change colours
fig_genre.update_traces(marker_color='rgb(148, 103, 189)')

#show plot
fig_genre.show()
# Out:
# <div>
#
#
#             <div id="444b6779-f694-40b9-9c1d-c207642c6c3f" class="plotly-graph-div" style="height:500px; width:480px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("444b6779-f694-40b9-9c1d-c207642c6c3f")) {
#                     Plotly.newPlot(
#                         '444b6779-f694-40b9-9c1d-c207642c6c3f',
#                         [{"alignmentgroup": "True", "hovertemplate": "variable=genre<br>value=%{x}<br>index=%{y}<extra></extra>", "legendgroup": "genre", "marker": {"color": "rgb(148, 103, 189)"}, "name": "genre", "offsetgroup": "genre", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [465, 441, 381, 358, 353, 348, 341, 304, 297], "xaxis": "x", "y": ["pop", "rock", "r&b/soul", "alternative", "punk", "pop/rock", "death-metal", "metal", "hip-hop/rap"], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 500, "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"b": 50, "l": 25, "pad": 0, "r": 25, "t": 50}, "template": {"data": {"bar": [{"error_x": {"color": "rgb(51,51,51)"}, "error_y": {"color": "rgb(51,51,51)"}, "marker": {"line": {"color": "rgb(237,237,237)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(237,237,237)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(51,51,51)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(51,51,51)"}, "baxis": {"endlinecolor": "rgb(51,51,51)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(51,51,51)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", ...

# %% [markdown]
# ## Count of Artist / Band

# %%
#subset on columns
df_suburst = df[['genre','artist','song']]

# %%
#create count column
df_suburst['count'] = 1

# %%
#create figure
fig_sunburst = px.sunburst(df_suburst, path=['genre', 'artist'], values='count',
                           color='genre',hover_name=None,hover_data=None)

#title parameters
title_param = dict(text='<b>Genre and Artists</b><br></b>', 
                   font=dict(size=20))

#margin parameters
margin_param=dict(l=25,r=25,b=50,t=50,pad=0)

#update layout
fig_sunburst.update_layout(title=title_param,
                           margin=margin_param,
                           width=1000,
                           height=1000)

#show plot
fig_sunburst.show()
# Out:
# <div>
#
#
#             <div id="1d91a358-1480-40fb-aef4-903a36ba05be" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1d91a358-1480-40fb-aef4-903a36ba05be")) {
#                     Plotly.newPlot(
#                         '1d91a358-1480-40fb-aef4-903a36ba05be',
#                         [{"branchvalues": "total", "customdata": [["rock"], ["metal"], ["punk"], ["pop"], ["rock"], ["r&b/soul"], ["rock"], ["alternative"], ["r&b/soul"], ["punk"], ["punk"], ["alternative"], ["rock"], ["hip-hop/rap"], ["alternative"], ["pop/rock"], ["death-metal"], ["death-metal"], ["pop/rock"], ["alternative"], ["alternative"], ["death-metal"], ["hip-hop/rap"], ["death-metal"], ["punk"], ["rock"], ["death-metal"], ["pop"], ["metal"], ["death-metal"], ["r&b/soul"], ["metal"], ["hip-hop/rap"], ["alternative"], ["punk"], ["pop/rock"], ["pop"], ["metal"], ["hip-hop/rap"], ["death-metal"], ["alternative"], ["punk"], ["hip-hop/rap"], ["pop/rock"], ["hip-hop/rap"], ["pop/rock"], ["alternative"], ["pop/rock"], ["rock"], ["r&b/soul"], ["punk"], ["hip-hop/rap"], ["punk"], ["punk"], ["death-metal"], ["pop"], ["metal"], ["pop"], ["punk"], ["death-metal"], ["hip-hop/rap"], ["alternative"], ["r&b/soul"], ["punk"], ["death-metal"], ["r&b/soul"], ["r&b/soul"], ["death-metal"], ["death-metal"], ["death-metal"], ["punk"], ["death-metal"], ["death-metal"], ["pop/rock"], ["death-metal"], ["death-metal"], ["death-metal"], ["punk"
# Let's look at the distribution of lyric length

# %%
#empty list
lyric_count_df = []

# %%
#loop through each unique genre
for i in df.genre.unique():
    
    #get subset of genres appended to list
    lyric_count_df.append(pd.DataFrame(df[df.genre == i]['lyric_count']))
    
#concat all DataFrames where each column is a genre
word_counts = pd.concat([i for i in lyric_count_df],axis=1)

# %%
#update columns
word_counts.columns = df.genre.unique()

# %%
#plot lyric count distributon for each genre
fig_dist = word_counts.plot.box(template='ggplot2')

#title parameters
title_param = dict(text='<b>Distribution of lyric length by genre</b><br></b>', 
                        font=dict(size=20))

#margin parameters
margin_param=dict(l=25,r=25,b=50,t=50,pad=0)

#update layout
fig_dist.update_layout(title=title_param,
                       margin=margin_param,
                       width=900,
                       height=500,  
                       xaxis = dict(title_text='Genre',title_font = dict(size=10),tickfont=dict(size=10)),
                       yaxis = dict(title_text='Song lyric length (n words)',title_font = dict(size=10),tickfont=dict(size=10)))

#update colours
fig_dist.update_traces(marker_color='rgb(148, 103, 189)')

#show plot
fig_dist.show()
# Out:
# <div>
#
#
#             <div id="7e74a5da-6af5-4215-b064-78f9d31a3793" class="plotly-graph-div" style="height:500px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7e74a5da-6af5-4215-b064-78f9d31a3793")) {
#                     Plotly.newPlot(
#                         '7e74a5da-6af5-4215-b064-78f9d31a3793',
#                         [{"alignmentgroup": "True", "hovertemplate": "variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "rgb(148, 103, 189)"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "pop", "p ...

# %% [markdown]
# # PoS Analysis

# %% [markdown]
# In order to perform part of speech analysis we need use something like spaCy

# %%
#load spacy model
nlp = spacy.load('en_core_web_lg')

# %%
def pos(string,pos):
    
    """Returns any token that qualifies as a specific part of speech"""
    
    doc = nlp(string) #fit model
    
    return ' '.join(list(set([i.text for i in doc if i.pos_ == pos]))) #return any tokens that qualify

# %%
#get nouns
df['nouns'] = df.lyrics.map(lambda x: pos(x,'NOUN'))

# %%
#get verbs
df['verbs'] = df.lyrics.map(lambda x: pos(x,'VERB'))

# %%
#get adjectives
df['adjectives'] = df.lyrics.map(lambda x: pos(x,'ADJ'))

# %%
#get adverbs
df['adverbs'] = df.lyrics.map(lambda x: pos(x,'ADV'))

# %% [markdown]
# Let's inspect the new columns..

# %%
# subset on new columns
df.iloc[1566:1568][df.columns[8:]]
# Out:
#                                                   nouns  \
# 1566  want times boulevard story cross shelter eyes ...
# 1567  ones sinner name road miracles winds tomorrow ...
#
#                                                   verbs  \
# 1566  burning saw bear left caught changed take keep...
# 1567  say mines let swallow paved goes hear got rais...
#
#                                            adjectives  \
# 1566  crazy same fast old full round second graceless
# 1567   guilty hopeless bitter cynical hungry innocent
#
#                                        adverbs
# 1566  around just even still away round rather
# 1567             differently how up about when

# %% [markdown]
# A function that can count the most common PoS will be helpful

# %%
def mostcommonTokens(data,additional_stopwords = [],token=1):
    
    """Returns a DataFrame of the most common n (arg)tokens in a string. Excludes stop words. Additional
    stop words can be added"""
    
    #add any new stop words to default stopword list
    add_stop_words = ENGLISH_STOP_WORDS.union(additional_stopwords)

    #instantiate count vectorizer and specify tokens
    vect = CountVectorizer(stop_words=add_stop_words, ngram_range= (token,token))

    #fit vectorizer
    X = vect.fit_transform(data)
    
    #get word counts as DataFrame
    word_counts = pd.DataFrame(np.asarray(X.sum(axis=0))[0],vect.get_feature_names(),columns=['count'])
    
    #sort by count
    word_counts = word_counts.sort_values(by='count', ascending=False)

    return word_counts #return DataFrame

# %% [markdown]
# Let's look at the top 10 words in the whole lyric corpus

# %%
#call the function on one gram
mostcommonTokens(df.lyrics,token=1).head(10)
# Out:
#       count
# like   4182
# know   3789
# just   3609
# yeah   3488
# love   3486
# got    3466
# oh     3465
# want   2895
# time   2220
# let    1963

# %% [markdown]
# We can integrate the mostcommonTokens function with Treemap visualisations to make the analysis clearer

# %%
def genreMap(df,pos,n=100):
    
    """Visualisation function. Returns a treemap of the most common n tokens that qualify as a part of speech"""
    
    #list to populate subset DataFrame's
    all_df = []

    #loop through unique genres
    for i in df.genre.unique():

        #get most common tokens for part of speech
        temp_df = mostcommonTokens(df[df['genre'] == i][pos]).head(n)
        
        #add column for current genre
        temp_df['genre'] = i

        #append DataFrame to list
        all_df.append(temp_df)

    #concatenate all DataFrame's
    all_df = pd.concat([i for i in all_df])

    #reset index
    all_df.reset_index(drop=False,inplace=True)

    #column labels
    all_df.columns = ['word','count','genre']

    # in order to have a single root node add 'all genres'
    all_df["all genres"] = "all genres" 

    #create plotly treemap figure
    fig = px.treemap(all_df, path=['all genres', 'genre', 'word'], values='count',)
    
    #title parameters
    title_param = dict(text='<b>Most Common Nouns, by genre</b><br>spaCy used for classifying PoS</b>', 
                        font=dict(size=20))
    
    #update layout
    fig.update_layout(title=title_param,
                    font= dict(family='Helvetica',size=10),
                    width=900,
                    height=900,
                    autosize=False,
                    margin=dict(l=40,r=40,b=85,t=100,pad=0,))
        
    #show plot
    fig.show()
    
    return fig

# %%
fig_nouns = genreMap(df,'nouns')
# Out:
# <div>
#
#
#             <div id="6b71b90a-a809-44c4-ad53-33a98e859fb9" class="plotly-graph-div" style="height:900px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6b71b90a-a809-44c4-ad53-33a98e859fb9")) {
#                     Plotly.newPlot(
#                         '6b71b90a-a809-44c4-ad53-33a98e859fb9',
#                         [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["all genres/death-metal/air", "all genres/hip-hop/rap/air", "all genres/metal/air", "all genres/pop/air", "all genres/r&b/soul/air", "all genres/rock/air", "all genres/r&b/soul/answer", "all genres/pop/arms", "all genres/punk/arms", "all genres/r&b/soul/arms", "all genres/hip-hop/rap/ass", "all genres/punk/ass", "all genres/pop/babe", "all genres/r&b/soul/babe", "all genres/rock/babe", "all genres/alternative/baby", "all genres/hip-hop/rap/baby", "all genres/pop/baby", "all genres/pop/rock/baby", "all genres/punk/baby", "all genres/r&b/soul/baby", "all genres/rock/baby", "all genres/hip-hop/rap/bag", "all genres/punk/band", "all genres/death-metal/beast", "all genres/hip-hop/rap/beat", "all genres/alternative/bed", "all genres/pop/bed", "all genres/pop/rock/bed", "all genres/punk/bed", "all genres/rock/bed", "all genres/hip-hop/rap/beef", "all genres/alternative/bit", "all genres/hip-hop/rap/bit", "all genres/punk/bit", "all genres/hip-hop/rap/bitch", "all genres/hip-hop/rap/bitches", "all genres/death-metal/blade", "all genres/hip-hop/rap/block", "all genres/alternative/blood", "all genres/death-metal/blood", "all genres/metal/blood", "all genres/pop/blood", "all genres/pop/rock/blood", "all genres/punk/blood", "all genres/rock/blood", "all genres/death-metal/bodies", "all genres/alternative/body", "all genres/death-metal/body", "all genres/hip-hop/rap/body", "all genres/metal/body", "all genres/pop/body", "all genres/pop/rock/body", "all genres/r&b/soul/body", "all genres/rock/body", "all genres/death-metal/bone", "all genres/alternative/bones", "all genres/death-metal/bones", "all genres/metal/bones", "all genres/alternative/boy", "all genres/hip-hop/rap/boy", "all genres/pop/boy", "all genres/punk/boy", "all genres/r&b/soul/boy", "all genres/rock/boy", "all genres/hip-hop/rap/boys", "all genres/death-metal/brain", "all genres/hip-hop/rap/brain", "all genres/metal/brain", "all genres/punk/brain", "all genres/death-metal/breath", "all genres/metal/breath", "all genres/punk/breath", "all genres/r&b/soul/breath", "all genres/hip-hop/rap/brother", "all genres/r&b/soul/brother", "all genres/hip-hop/rap/car", "all genres/pop/car", "all genres/pop/rock/car", "all genres/punk/car", "all genres/hip-hop/rap/cash", "all genres/alternative/chance", "all genres/metal/chance", "all genres/pop/chance", "all genres/pop/rock/chance", "all genres/punk/chance", "all genres/r&b/soul/chance", "all genres/rock/chance", "all genres/alternative/child", "all genres/death-metal/child", "all genres/metal/child", "all genres/pop/rock/child", "all genres/r&b/soul/child", "all genres/rock/child", "all genres/death-metal/children", "all genres/metal/children", "all genres/r&b/soul/children", "all genres/hip-hop/rap/city", "all genres/pop/rock/city", "all genres/punk/city", "all genres/r&b/soul/city", "all genres/rock/city", "all genres/hip-hop/rap/clothes", "all genres/hip-hop/rap/club", "all genres/hip-hop/rap/comin", "all genres/metal/control", "all genres/pop/rock/control", "all genres/r&b/soul/control", "all genres/rock/control", "all genres/pop/rock/corner", "all genres/death-metal/corpse", "all genres/hip-hop/rap/couple", "all genres/hip-hop/rap/crew", "all genres/death-metal/cross", "all genres/rock/crowd", "all genres/pop/dance", "all genres/pop/rock/dark", "all genres/r&b/soul/dark", "all genres/death-metal/darkness", "all genres/metal/darkness", "all genres/pop/rock/darkness", "all genres/r&b/soul/darkness", "all genres/pop/darling", "all genres/r&b/soul/darling", "all genres/death-metal/dawn", "all genres/metal/dawn", "all genres/alternative/day", "all genres/death-metal/day", "all genres/hip-hop/rap/day", "all genres/metal/day", "all genres/pop/day", "all genres/pop/rock/day", "all genres/punk/day", "all genres/r&b/soul/day", "all genres/ro ...

# %% [markdown]
# # Load Universal Sentence Encoder

# %% [markdown]
# In order to get embeddings - we need to load the universal sentence encoder.

# %%
#get universal sentence encoder
USE = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# %%
def getUSEEmbed(_string,USE = USE):
    
    """Function takes a string argument and returns its high dimensional vector from USE"""
    
    return np.array(USE([_string])[0])

# %%
#call function to get embedding
example = getUSEEmbed('Hello how are you?')

# %% [markdown]
# Inspect shape of the vector

# %%
example.shape
# Out:
# (512,)

# %% [markdown]
# We can assess similarity by looking at **cosine similarity** of the vectors..
#
# The cosine similarity of two high dimensional vectors representing SIMILAR sentences should be high..
#
# For sentences that are DIFFERENT, the cosine similarity should be low..

# %%
#some example sentences
example_sentences = ["The weather is going to be really warm today",
                     
                     "Today is going to be the sunniest day of the year",
                     
                     "I like my eggs sunny side up",
                     
                     "Breakfast is my favourite meal"]

# %%
#get embeddings for each example sentence
embed = [getUSEEmbed(i) for i in example_sentences]

# %%
#set up a dictionary where each sentece is a key and its value is its 512 vector embedding
dic_ = dict(zip(example_sentences,embed))

# %%
#let's find all the unique pairwise sentence combinations
combo = [list(i) for i in itertools.combinations(example_sentences, 2)]

# %%
def cosineSimilarity(vec_x,vec_y):
    
    """Function returns pairwise cosine similarity of two vector arguments"""
    
    return cosine_similarity([vec_x],[vec_y])[0][0]

# %% [markdown]
# Let's make a DataFrame that maps the cosine similarity for each unique sentence pair

# %%
#empty list for data
cs = []

#lop through each unique sentence pairing
for i in range(len(combo)):
    
    #get cosine similarity for each
    cs_ = cosineSimilarity(dic_[combo[i][0]],dic_[combo[i][1]])
    
    #append data to list
    cs.append((combo[i][0],combo[i][1],cs_))

# %%
#construct DataFrame
cs_df = pd.DataFrame(cs,columns=['sent_1','sent_2','cosine_similarity']).\
                    sort_values(by='cosine_similarity',ascending=False)

# %% [markdown]
# Let's look at the data..

# %% [markdown]
# Sentences that are similar have higher cosine similarity. This mean the vectors that represent these sentences are similar. That's really impressive!

# %%
cs_df
# Out:
#                                               sent_1  \
# 0       The weather is going to be really warm today
# 5                       I like my eggs sunny side up
# 1       The weather is going to be really warm today
# 3  Today is going to be the sunniest day of the year
# 2       The weather is going to be really warm today
# 4  Today is going to be the sunniest day of the year
#
#                                               sent_2  cosine_similarity
# 0  Today is going to be the sunniest day of the year           0.519781
# 5                     Breakfast is my favourite meal           0.416550
# 1                       I like my eggs sunny side up           0.150719
# 3                       I like my eggs sunny side up           0.146834
# 2                     Breakfast is my favourite meal           0.139814
# 4                     Breakfast is my favourite meal           0.137269

# %% [markdown]
# # USE Embeddings

# %% [markdown]
# Let's apply this technique to get embeddings for each of our songs.

# %%
#get USE embeddings for each song
df_embed = pd.DataFrame([getUSEEmbed(df.lyrics[i]) for i in range(df.shape[0])],\
                        index=[df.song[i] for i in range(df.shape[0])])

# %% [markdown]
# The lyrics of each song are represented as high dimensional vectors

# %%
df_embed.head(20)
# Out:
#                                      0         1         2         3    \
# The One That Got Away acoustic  0.002838 -0.070699  0.071667 -0.005688
# Who Am I Living For            -0.031676 -0.070214  0.067109  0.056683
# Daisies                        -0.019871 -0.064819  0.038741 -0.032296
# Witness                        -0.008359 -0.049522  0.028044  0.038328
# Starstrukk                     -0.040732 -0.022921 -0.021097  0.031555
# Birthday                       -0.021830 -0.070009  0.070492  0.061501
# Save As Draft                  -0.008242 -0.081798 -0.032451  0.062998
# Walking on Air                  0.012115 -0.043124  0.064730  0.030730
# Firework                       -0.017788 -0.064830  0.069706  0.049199
# Unconditionally                -0.019738 -0.070386  0.007292  0.044800
# Rise                           -0.007894 -0.066405  0.040211  0.027702
# Choose Your Battles            -0.040676 -0.065068  0.052782  0.054291
# D%C3%A9j%C3%A0 Vu               0.049731 -0.071732 -0.026592  0.066582
# Roar                           -0.045100 -0.031304  0.065749  0.043524
# Daisies                         0.044725 -0.008223 -0.063309  0.021955
# Witness                        -0.041959 -0.037329 -0.039399 -0.018347
# Starstrukk                      0.032942  0.027877 -0.007560  0.070868
# Birthday                        0.035514  0.001723 -0.032653  0.035728
# Save As Draft                  -0.000484  0.018639 -0.013338  0.034465
# Walking on Air                  0.009974 -0.001454 -0.003591  0.036791
# Firework                       -0.021954  0.010146 -0.044114  0.027493
# Unconditionally                 0.020346  0.052851  0.007925  0.014083
# Rise                            0.052522 -0.022373 -0.001517  0.027586
# Choose Your Battles             0.006412  0.029787 -0.024294  0.023051
# D%C3%A9j%C3%A0 Vu              -0.000399  0.032349 -0.000813 -0.013604
# Roar                            0.039561  0.006227 -0.001731 -0.038381
# California Gurls               -0.040461 -0.028977 -0.058283  0.058394
# Thinking of You                 0.009962 -0.034043 -0.050574  0.053864
# Mind Maze                       0.048144  0.053637  0.023589 -0.035620
# Circle the Drain               -0.019403 -0.069880 -0.020410  0.016548
# Never Really Over               0.020248 -0.032698 -0.004520 -0.039218
# NaN                            -0.029238 -0.024581  0.032274  0.028844
#
#                                      508       509       510       511
# The One That Got Away acoustic  0.054640 -0.005483 -0.063760  0.025022
# Who Am I Living For            -0.045737  0.042120 -0.058688  0.057825
# Daisies                        -0.006814  0.013424  0.039509  0.031160
# Witness                         0.059835  0.037758 -0.045419  0.036411
# Starstrukk                     -0.024025 -0.015801 -0.026928  0.050967
# Birthday                       -0.021292 -0.030192 -0.061660 -0.011480
# Save As Draft                  -0.069218  0.050370 -0.046481 -0.035127
# Walking on Air                  0.005627  0.028063 -0.041480  0.053257
# Firework                       -0.064885  0.009179 -0.044942  0.034160
# Unconditionally                -0.023212  0.028777 -0.055214  0.022267
# Rise                           -0.046270  0.060885 -0.059326  0.045827
# Choose Your Battles            -0.026462  0.056902 -0.050383  0.023612
# D%C3%A9j%C3%A0 Vu              -0.053527  0.042391 -0.039216 -0.042949
# Roar                           -0.002117  0.060538 -0.059322  0.025851
# California Gurls                0.052397 -0.033259 -0.053287 -0.045176
# Thinking of You                -0.013356  0.055178 -0.053661 -0.013674
# Mind Maze                      -0.048321  0.062377 -0.024426 -0.020975
# Circle the Drain                0.012384  0.004612 -0.022734 -0.004539
# Never Really Over              -0.062705  0.031865 -0.068943  0.018933
# NaN                            -0.024822  0.011906 -0.036651  0.024324
#
# [20 rows x 512 columns]

# %% [markdown]
# Let's use another data reduction technique - Principal Component Analysis, to reduce the dimensionality of these embeddings whilst retaining as much variance as possible.

# %%
def MusixmatchPCA(df,df_embedding,n_components):
    
    """Function uses PCA to reduce dimensionality of the USE embeddings for each song
    returning a DataFrame with either 1,2,3 PC's"""
    
    cols = df_embedding.index
    
    embeddings = df_embedding.iloc[:, 1:] #subset on embeddings only
    
    pca = PCA(n_components=n_components) #instantiate PCA

    pca.fit(embeddings) #fit the embeddings

    new_values = pca.transform(embeddings) #transform / reduce data
    
    #let's see how much variance can be explained
    print(pca.explained_variance_ratio_.cumsum()) 
    
    #option to have 1,2 columns / components
    if n_components == 2:
        
        columns = ['pca_x','pca_y']
        
    elif n_components == 3:
        
        columns = ['pca_x','pca_y','pca_z']
        
    else: 
        columns = ['pc']
    
    df_reduced = pd.DataFrame(new_values,index=cols) #get new DataFrame
    
    df_reduced.columns = columns
    
    if n_components == 1:
        
        df_reduced.sort_values(by='pc',ascending=False,inplace=True)
    
    #merges PCA DataFrame on original DataFrame
    df_merge = pd.merge(df,df_reduced,how='inner',left_on='song',right_on=df_reduced.index)
    
    return df_merge #returns merged DataFrame

# %% [markdown]
# As we can see, the cumulative variance that is explained when we reduce 512 dimensions down to n = 1,2,3 is pretty poor. Let's continue with this for now and see if we still get useful results.

# %%
pc_1 = MusixmatchPCA(df,df_embed,n_components=1)
pc_2 = MusixmatchPCA(df,df_embed,n_components=2)
pc_3 = MusixmatchPCA(df,df_embed,n_components=3)
# Out:
# [0.0729287]
# [0.0729287  0.11527749]
# [0.0729287  0.11527749 0.14892874]

# %% [markdown]
# Let's do some grouping to explore which artists have lyrics that are most similar to each other
#
# As we can see - even with one component, artists from genres tend to cluster together. Death metal, heavy metal and rock differ slighty from one another but vastly different to pop and soul. This makes sense!

# %%
#DataFrame of grouped data
pc1_group = pd.DataFrame(pc_1.groupby('artist')['pc'].mean())

#sort values by principal component and plot data
fig_lyric_sim_art = pc1_group.sort_values(by='pc').plot.barh(labels=dict(variable="artist", value="PC"),
                               template='ggplot2')

#title parameters
title_param = dict(text='<b>Lyric similarity, by artist</b><br>Based on Principal Component 1</b>', 
                        font=dict(size=20))

#margin parameters
margin_param=dict(l=40,r=40,b=85,t=200,pad=0)

#update figure
fig_lyric_sim_art.update_layout(title=title_param,
                                width=1000,
                                height=3000,
                                margin = margin_param,
                                xaxis = dict(title='Principal Component 1'))
#show figure
fig_lyric_sim_art.show()
# Out:
# <div>
#
#
#             <div id="33a2d7f1-90d9-4bb5-8015-21a56f24e536" class="plotly-graph-div" style="height:3000px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("33a2d7f1-90d9-4bb5-8015-21a56f24e536")) {
#                     Plotly.newPlot(
#                         '33a2d7f1-90d9-4bb5-8015-21a56f24e536',
#                         [{"alignmentgroup": "True", "hovertemplate": "artist=%{y}<br>PC=%{x}<extra></extra>", "legendgroup": "pc", "marker": {"color": "#F8766D"}, "name": "pc", "offsetgroup": "pc", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [-0.3102310917359254, -0.2785275120102043, -0.27745370231935435, -0.2532322069699532, -0.24274401919775002, -0.20395814252635183, -0.20220590915492748, -0.19332048878461328, -0.1786261271049678, -0.17761320134320815, -0.1755798616357381, -0.17482560130005448, -0.17322914331746037, -0.16705396094573102, -0.16605219492212567, -0.16452443997680602, -0.16235011306817973, -0.15694292204238744, -0.14800178877191972, -0.14431484582730592, -0.13800766839821507, -0.13717334176963075, -0.13480884467458124, -0.13165078305532862, -0.12893718625680903, -0.12642853877782106, -0.12539919065909258, -0.12465255713122268, -0.12005136437764453, -0.11843504046520464, -0.11341430634487587, -0.10336923652274306, -0.09767020698527124, -0.09628979079616322, -0.09191431144073366, -0.09046411721231735, -0.08238176176658965, -0.08236910865786179, -0.08193731119297586, -0.08173078818951196, -0.08163704722367648, -0.07082989783313821, -0.06869220716572542, -0.06379153797527846, -0.05
is": {"endlinecolor": "rgb(51,51,51)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(51,51,51)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"ou

# %% [markdown]
#  Let's look at the same analysis but grouped by genres.
#
# This confirms what we found above, the lyrics in genres cluster into groups that make sense.

# %%
#DataFrame of grouped data
pc1_group = pd.DataFrame(pc_1.groupby('genre')['pc'].mean())

#sort values by principal component and plot data
fig_lyric_sim_genre = pc1_group.sort_values(by='pc').plot.bar(labels=dict(variable="genre", value="PC"),\
                               template='ggplot2')

#title parameters
title_param = dict(text='<b>Lyric similarity, by genre</b><br>Based on Principal Component 1</b>', 
                        font=dict(size=20))

#margin parameters
margin_param=dict(l=40,r=40,b=85,t=200,pad=0)

#update figure
fig_lyric_sim_genre.update_layout(
                      title=title_param,
                      width=1000,
                      height=900,
                      margin=margin_param,
                      xaxis = dict(title='Genre'),
                      yaxis = dict(title='Principal Component 1'))
#show figure
fig_lyric_sim_genre.show()
# Out:
# <div>
#
#
#             <div id="9c27ed85-c15e-4f69-80bc-75be8935af58" class="plotly-graph-div" style="height:900px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9c27ed85-c15e-4f69-80bc-75be8935af58")) {
#                     Plotly.newPlot(
#                         '9c27ed85-c15e-4f69-80bc-75be8935af58',
#                         [{"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>PC=%{y}<extra></extra>", "legendgroup": "pc", "marker": {"color": "#F8766D"}, "name": "pc", "offsetgroup": "pc", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["r&b/soul", "pop", "pop/rock", "rock", "hip-hop/rap", "alternative", "punk", "metal", "death-metal"], "xaxis": "x", "y": [-0.17676970624987082, -0.12652533942413557, -0.09388991617980322, -0.07417428428843366, 0.0022551549244971647, 0.0024721849029502013, 0.04503748090486289, 0.1805813050578476, 0.3496883297746332], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 900, "legend": {"title": {"text": "genre"}, "tracegroupgap": 0}, "margin": {"b": 85, "l": 40, "pad": 0, "r": 40, "t": 200}, "template": {"data": {"bar": [{"error_x": {"color": "rgb(51,51,51)"}, "error_y": {"color": "rgb(51,51,51)"}, "marker": {"line": {"color": "rgb(237,237,237)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(237,237,237)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(51,51,51)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(51,51,51)"}, "baxis": {"endlinecolor": "rgb(51,51,51)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(51,51,51)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "colorscale": [[0, "rgb(20,44,66)"], [1, "rgb(90,179,244)"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", "ticklen": 6, "ticks": "inside"}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {"outlinewidth": 0, "tickcolor": "rgb(237,237,237)", " ...

# %% [markdown]
# Let's make a more sophisticated visualisation that uses scatter plots to show this data by song.
#
# We can look at this in two dimensions (PC1,PC2) but also in three dimensions (PC1,PC2,PC3)

# %% [markdown]
# # Plotting

# %%
def Musixmatch_scatPlot(df,df_embed,n_components=2):
    
    """Comprehensive function that adds components to a scatter plot"""
    
    df = MusixmatchPCA(df,df_embed,n_components) #gets PCA
             
    fig = go.Figure() #instantiate Ploty.go object

    genres = df.genre.unique() #get unique genres     
    
    for i in range(len(genres)): #loop through genres

        df_mask = df[df.genre == genres[i]] #subset on genre
        
        df_mask['artist_song'] = df_mask['artist']+' // '+df_mask['song'] #new labels for traces
             
        if n_components == 2:
            
            #add traces for 2d - several formatting options for hover text, and marker size
            fig.add_trace(go.Scatter(
                          x=df_mask['pca_x'],
                          y=df_mask['pca_y'],
                          name=genres[i],
                          text=df_mask['artist_song'],
                          mode='markers',hoverinfo='text',
                          marker={'size':df_mask.lyric_count_norm}))
        
        else:
            #add traces for 3d - several formatting options for hover text, and marker size
            fig.add_trace(go.Scatter3d(
                          x=df_mask['pca_x'],
                          y=df_mask['pca_y'],
                          z=df_mask['pca_z'],
                          name=genres[i],
                          text=df_mask['artist_song'],
                          mode='markers',hoverinfo='text',
                          marker={'size':df_mask.lyric_count_norm}))
    # axis parameters
    axis_x_param=dict(showline=True, 
                      zeroline=True,
                      showgrid=True,
                      showticklabels=True,
                      title='Principal Component 1')
    # axis parameters
    axis_y_param=dict(showline=True, 
                      zeroline=True,
                      showgrid=True,
                      showticklabels=True,
                      title='Principal Component 2')
    
    # legend parameters
    legend_param= dict(bgcolor=None,
                       bordercolor = None,
                       borderwidth = None,
                       font = dict(family='Open Sans',size=15,color=None),
                       orientation='v',
                       itemsizing='constant',
                       title=dict(text='Genres (clickable!)',
                                  font=dict(family='Open Sans',size=20,color=None),
                                  side='top'),)
    # margin parameters
    margin_param=dict(l=40,r=40,b=85,t=200,pad=0)
    
    # title parameters
    title_param = dict(text='<b>Similarities and differences in song lyrics by genre</b>\
    <br>Universal sentence encodings and dimensionality reduction - trace size represents lyric count.', 
                        font=dict(size=20))
    
    #update layout
    fig.update_layout(legend= legend_param,
                      title=title_param,
                      width=1000,
                      height=1000,
                      showlegend=True,
                      xaxis=axis_x_param,
                      yaxis=axis_y_param,
                      margin=margin_param,)

    fig.show()    
    return fig

# %%
scatPlot_2 = Musixmatch_scatPlot(df,df_embed,n_components=2)
# Out:
# [0.0729287  0.11527749]
# <div>
#
#
#             <div id="2fbffb40-6624-444b-a8f2-9af09a8148f1" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2fbffb40-6624-444b-a8f2-9af09a8148f1")) {
#                     Plotly.newPlot(
#                         '2fbffb40-6624-444b-a8f2-9af09a8148f1',
#                         [{"hoverinfo": "text", "marker": {"size": [7.4892174984596425, 6.438693776956254, 5.320394331484905, 7.895871842267407, 5.794824399260628, 7.624768946395564, 6.879235982747997, 4.981515711645101, 7.895871842267407, 5.422057917436845, 6.709796672828096, 6.2014787430683915, 4.77818853974122, 5.96426370918053, 10.369685767097966, 7.929759704251386, 5.286506469500924, 8.23475046210721, 7.929759704251386, 7.319778188539741, 7.319778188539741, 7.319778188539741, 7.319778188539741, 7.319778188539741, 7.319778188539741, 4.608749229821319, 4.608749229821319, 4.608749229821319, 4.608749229821319, 4.608749229821319, 4.608749229821319, 7.692544670363525, 7.692544670363525, 7.692544670363525, 7.692544670363525, 7.692544670363525, 7.692544670363525, 9.319162045594577, 6.980899568699938, 11.216882316697474, 5.4559457794208255, 8.607516943930992, 8.43807763401109, 5.218730745532964, 5.252618607516944, 6.269254467036353, 6.777572396796057, 5.591497227356746, 8.43807763401109, 8.065311152187308, 14.029574861367838, 5.557609365372767, 8.099199014171287, 6.675908810844116, 12.199630314232902, 6.743684534812076, 10.234134319162045, 7.116451016635859, 8.166974738139249, 6.642020948860136, 6.675908810844116, 6.980899568699938, 7.556993222427603, 6.472581638940234, 14.673444239063464, 5.625385089340727, 5.557609365372767, 9.081947011706715, 6.879235982747997, 8.53974121996303, 7.455329636475662, 8.166974738139249, 7.692544670363525, 9.353049907578557, 7.116451016635859, 8.810844115834874, 5.625385089340727, 16.028958718422672, 11.454097350585336, 9.353049907578557, 21.41712877387554, 13.25015403573629, 8.912507701786813, 9.895255699322243, 11.589648798521257, 6.303142329020332, 5.184842883548983, 10.335797905113987, 11.657424522489219, 9.420825631546519, 15.215650030807